# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("TDG-Ch2")
    .master("local[*]")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.2.0.2:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>TDG-Ch2</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.range(1000)
df.count()
# Out:
# 1000

# %%
df.filter("id > 900").show()
# Out:
# +---+
# | id|
# +---+
# |901|
# |902|
# |903|
# |904|
# |905|
# |906|
# |907|
# |908|
# |909|
# |910|
# |911|
# |912|
# |913|
# |914|
# |915|
# |916|
# |917|
# |918|
# |919|
# |920|
# +---+
# only showing top 20 rows

# %%
flight_path = "data/flight-data/json/2015-summary.json"
flight_df = spark.read.json(flight_path)

flight_df.show(5)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |    United States|            Romania|   15|
# |    United States|            Croatia|    1|
# |    United States|            Ireland|  344|
# |            Egypt|      United States|   15|
# |    United States|              India|   62|
# +-----------------+-------------------+-----+
# only showing top 5 rows
